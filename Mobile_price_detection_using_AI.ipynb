# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import io
data= files.upload()
# Out:
#      <input type="file" id="files-d09c9003-67cd-4a1c-bb7e-49d503b67272" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d09c9003-67cd-4a1c-bb7e-49d503b67272">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_train=pd.read_csv(io.StringIO(data['Mobile_train.csv'].decode('utf-8')))

# %%
data_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
data_test=pd.read_csv(io.StringIO(data['Mobile_train.csv'].decode('utf-8')))

# %%
data_test
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
data_train.shape
# Out:
# (2000, 21)

# %%
data_test.shape
# Out:
# (2000, 21)

# %%
data_train.isnull().sum()
#checking for null values
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data_train.plot(kind='box')

#checking for outliers

# %%
X=data_train.drop("price_range",axis=1) #copying all features to X except label price range for scaling purpose

# %%
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
Y=data_train['price_range'] #copying price range to Y

# %%
Y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.30,random_state=0,stratify=Y)

# %%
print("X_train shape:",X_train.shape)
print("Y_train shape:",y_train.shape)
# Out:
# X_train shape: (1400, 20)
# Y_train shape: (1400,)

# %%
print("X_test shape:",X_test.shape)
print("y_test shape:",y_test.shape)
# Out:
# X_test shape: (600, 20)
# y_test shape: (600,)

# %% [markdown]
# Scaling

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=4)

knn.fit(X_train, y_train)

print("Test set accuracy: {:.2f}".format(knn.score(X_test, y_test)))
# Out:
# Test set accuracy: 0.90

# %%
#MinMax Scaler
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)

X_test_scaled = scaler.transform(X_test)

#train
knn.fit(X_train_scaled, y_train)

# scoring on the scaled test set
print("MinMax Scaled test set accuracy: {:.2f}".format(
    knn.score(X_test_scaled, y_test)))
# Out:
# MinMax Scaled test set accuracy: 0.36

# %%
#Standard Scaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# learning an SVM on the scaled training data
knn.fit(X_train_scaled, y_train)

# scoring on the scaled test set
print("Standard Scaled test accuracy: {:.2f}".format(knn.score(X_test_scaled, y_test)))

#Hence Standard Scaling in used as it has higher accuracy score
# Out:
# Standard Scaled test accuracy: 0.50

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
clf = DecisionTreeClassifier(criterion='entropy',random_state=1)
clf.fit(X_train_scaled,y_train)
y_pred_dt = clf.predict(X_test_scaled)
clf_score=accuracy_score(y_pred_dt,y_test)
print(clf_score)
# Out:
# 0.845

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=750)
tree.plot_tree(clf,
               feature_names = X.columns,
               class_names=['0','1','2','3'],
               filled = True);

# %%
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test,y_pred_dt)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0,1,2,3])

cm_display.plot()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(X['int_memory'],Y)

# %%
import matplotlib.pyplot as plt
plt.scatter(X['ram'],Y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr=LogisticRegression()
lr.fit(X_train_scaled, y_train)
y_pred_lr=lr.predict(X_test_scaled)
lr_score=accuracy_score(y_pred_lr,y_test)
print(lr_score)
# Out:
# 0.96

# %%
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test,y_pred_lr)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0,1,2,3])

cm_display.plot()
plt.show()

# %%
#will use for histogram

# %%
#KNN Model starts here

from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=4)

# %%
knn.fit(X_train_scaled,y_train) #Training
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
y_pred= knn.predict(X_test_scaled)  #Testing; giving predictions to y_pred

# %%
print("Test set score/Accuracy : {:.2f}".format(np.mean(y_pred==y_test)))  #Accuracy=(1-error), where error=no.of_mismatch/len(y_pred)
# Out:
# Test set score/Accuracy : 0.50

# %%
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test,y_pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0,1,2,3])

cm_display.plot()
plt.show()

# %%
import seaborn as sns
sns.heatmap(data_test)
plt.show()

# %%
fig,ax = plt.subplots()
ax.hist(y_train)
ax.set_title('Frequency of  Classes')
ax.set_xlabel('class label')
ax.set_ylabel('no. of phones')
# Out:
# Text(0, 0.5, 'no. of phones')

# %%
data={'DT':clf_score, 'KNN':np.mean(y_pred==y_test), 'LR':lr_score}
models=list(data.keys())
scores=list(data.values())
fig = plt.figure(figsize = (10, 5))
plt.bar(models,scores, color='blue', width=0.5)
plt.xlabel("model names")
plt.ylabel("accuracy score")
plt.title("models used and their accuracies")
plt.show()
